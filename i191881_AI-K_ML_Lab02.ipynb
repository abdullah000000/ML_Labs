# %% [markdown]
# Question #01

# %%
# create a Python class with a constructor and functions of all access specifiers each.
class MyClass:
    def __init__(self, name):
        self.name = name
        print("Hello World Parent")
    def public(self):
        print("Public")
    def _protected(self):
        print("Protected")
    def __private(self):
        print("Private")

# %%
obj = MyClass("Hello World")
# Out:
# Hello World Parent

# %%
#main function to call all the functions of the class
if __name__ == '__main__':
    obj.public()
    obj._protected()
    # obj.__private() # this will give an error
# Out:
# Public
# Protected

# %%
# Inherit a subclass from the above created class, initiate its
# constructor that also initiates the parent class’ constructor. 
class MySubClass(MyClass):
    def __init__(self, name2):
        super().__init__(name2)
        self.name2 = name2

    # Add a function in this subclass
    def my_function(self):
        print("Child Function")

# %%
# Create an object of parent class and call its functions. Create an object of child class and try accessing child functions as well as parent class functions.
obj1 = MyClass("1")
obj1.public()
obj1._protected()
# obj1.__private() # this will give an error
obj2 = MySubClass("2")
obj2.my_function()
# Out:
# Hello World Parent
# Public
# Protected
# Hello World Parent
# Child Function

# %% [markdown]
# Question # 02

# %%
# Use enumerate in a scenario of your own choice
for i, j in enumerate([1, 2, 3, 4, 5]):
    print(i, j)
# Out:
# 0 1
# 1 2
# 2 3
# 3 4
# 4 5

# %% [markdown]
# Question # 03

# %%
# Given a list of strings, return the count of the number of strings where the string length is 2 or more and the first and last chars of the string are the same
def match_words(words):
    count = 0
    for word in words:
        if len(word) >= 2 and word[0] == word[-1]:
            count += 1
    return count

# %%
print(match_words(['def', 'abc', 'ded', '3443']))
# Out:
# 2

# %% [markdown]
# Question # 04

# %%
# Given a list of strings, return a list with the strings in sorted order,except group all the strings that begin with 'x' first.
# e.g. ['mix', 'xyz', 'apple', 'xanadu', 'aardvark'] yields ['xanadu', 'xyz', 'aardvark', 'apple', 'mix']
# Hint: use sorted() and lambda.
def front_x(words):
    return sorted(words, key=lambda x: x[0] == 'x') + sorted(words, key=lambda x: x[0] != 'x')

# %%
print(front_x(['mix', 'xyz', 'apple', 'xanadu', 'aardvark']))
# Out:
# ['mix', 'apple', 'aardvark', 'xyz', 'xanadu', 'xyz', 'xanadu', 'mix', 'apple', 'aardvark']

# %% [markdown]
# Question # 05

# %%
# Given a list of non-empty tuples, return a list sorted in increasing order by the last element in each tuple.
def sort_last(tuples):
    return sorted(tuples, key=lambda x: x[-1])

# %%
print(sort_last([(1, 7), (1, 3), (3, 4, 5), (2, 2)]))
# Out:
# [(2, 2), (1, 3), (3, 4, 5), (1, 7)]

# %% [markdown]
# Question # 06

# %%
# Given a list of numbers, return a list where all adjacent == elements have been reduced to a single element, so [1, 2, 2, 3] returns [1, 2, 3].
def remove_adjacent(nums):
    return [nums[i] for i in range(len(nums)) if i == 0 or nums[i - 1] != nums[i]]

# %%
print(remove_adjacent([1, 2, 2, 3]))
# Out:
# [1, 2, 3]

# %% [markdown]
# Question # 07

# %%
# two lists sorted in increasing order, create and return a merged list of all the elements in sorted order
def linear_merge(list1, list2):
    return sorted(list1 + list2)

# %%
print(linear_merge(['aa', 'xx', 'zz'], ['bb', 'cc']))
# Out:
# ['aa', 'bb', 'cc', 'xx', 'zz']

# %% [markdown]
# CSV Related Tasks

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("/home/abdullah/Downloads/drinks.csv")

# %%
df
# Out:
#          country  beer_servings  spirit_servings  wine_servings  \
# 0    Afghanistan              0                0              0
# 1        Albania             89              132             54
# 2        Algeria             25                0             14
# 3        Andorra            245              138            312
# 4         Angola            217               57             45
# ..           ...            ...              ...            ...
# 188    Venezuela            333              100              3
# 189      Vietnam            111                2              1
# 190        Yemen              6                0              0
# 191       Zambia             32               19              4
# 192     Zimbabwe             64               18              4
#
#      total_litres_of_pure_alcohol continent
# 0                             0.0        AS
# 1                             4.9        EU
# 2                             0.7        AF
# ...

# %%
# Display the total number of rows 
df.shape[0]
# Out:
# 193

# %%
# Drop na values
df.dropna()
# Out:
#          country  beer_servings  spirit_servings  wine_servings  \
# 0    Afghanistan              0                0              0
# 1        Albania             89              132             54
# 2        Algeria             25                0             14
# 3        Andorra            245              138            312
# 4         Angola            217               57             45
# ..           ...            ...              ...            ...
# 188    Venezuela            333              100              3
# 189      Vietnam            111                2              1
# 190        Yemen              6                0              0
# 191       Zambia             32               19              4
# 192     Zimbabwe             64               18              4
#
#      total_litres_of_pure_alcohol continent
# 0                             0.0        AS
# 1                             4.9        EU
# 2                             0.7        AF
# ...

# %%
# A function that takes name of the coloumn and outputs the data in the column
def coloumn_data(coloumn_name):
    return df[coloumn_name]

# %%
coloumn_data("total_litres_of_pure_alcohol")
# Out:
# 0       0.0
# 1       4.9
# 2       0.7
# 3      12.4
# 4       5.9
#        ...
# 188     7.7
# 189     2.0
# 190     0.1
# 191     2.5
# 192     4.7
# Name: total_litres_of_pure_alcohol, Length: 193, dtype: float64

# %%
# plot histogram of the data with labels
df.hist()
plt.xlabel("Total Litres of Pure Alcohol")
plt.ylabel("Frequency")
plt.title("Histogram of Total Litres of Pure Alcohol")
plt.show()

# %%
#plot a scatter plot in 2D
df.plot.scatter(x="total_litres_of_pure_alcohol", y="beer_servings")
plt.xlabel("Total Litres of Pure Alcohol")
plt.ylabel("Beer Servings")
plt.title("Scatter Plot of Total Litres of Pure Alcohol vs Beer Servings")
plt.show()

# %%
# plot scatter plot in 3D
from mpl_toolkits.mplot3d import Axes3D
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.scatter(df["total_litres_of_pure_alcohol"], df["beer_servings"], df["wine_servings"])
ax.set_xlabel("Total Litres of Pure Alcohol")
ax.set_ylabel("Beer Servings")
ax.set_zlabel("Wine Servings")
plt.title("Scatter Plot of Total Litres of Pure Alcohol vs Beer Servings vs Wine Servings")
plt.show()

# %%
# plot pie chart of the data
plt.pie(df["total_litres_of_pure_alcohol"], labels=df["country"])
plt.title("Pie Chart of Total Litres of Pure Alcohol")
plt.show()

# %%
#plot bar chart of the data
plt.bar(df["country"], df["total_litres_of_pure_alcohol"])
plt.xlabel("Country")
plt.ylabel("Total Litres of Pure Alcohol")
plt.title("Bar Chart of Total Litres of Pure Alcohol")
plt.show()

# %%
#Plot above charts for three variables
plt.pie(df["total_litres_of_pure_alcohol"], labels=df["country"])
plt.title("Pie Chart of Total Litres of Pure Alcohol")
plt.show()
